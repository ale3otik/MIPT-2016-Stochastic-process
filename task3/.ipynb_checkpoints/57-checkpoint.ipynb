# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sps
import math
import scipy
from collections import Counter
import copy
# %matplotlib inline

# %% [markdown]
# Приблизим процесс следующим образом:
#
# $X_t = \frac{\xi_0 t }{\sqrt{\pi}} + \sqrt{\frac{2}{\pi}} {\sum_{n=1}^{precision}} \frac{\sin(kt)}{k} \xi_k$ , где
# $\xi_k \sim N(0,1) , t \in [0, \pi]$.
#
# Продолжим на $\mathbb{R} +$ как  $X_t = \sqrt{\pi} \sum_{n=0}^{m-1}\xi_{0_n} + X_{t_2}$ , где $ \pi m \leq t < \pi (m+1)$ , $t_2 = t - \pi m $.

# %%
class WinerProcess:
    def __init__(self,precision=10000):
        if precision == 0:
            precision = 1
        
        self.precision = precision
        self.eps = 1e-20
        self.ksi_0 = []
        self.ksi = dict()

        self._calc_X_vect = np.vectorize(self._calc_X)
        self._get_bound_vect = np.vectorize(self._get_bound)
    
#     returns k that time in [k*\pi; (k+1)*\pi]
    def _get_bound(self,time):
        return int(time/np.pi + self.eps)

    def _calc_X(self,t):
        k = self._get_bound(t)
        t -= np.pi * k
        x = np.sum([self.ksi[k][i-1] * np.sin(i * t) / i for i in range(1,self.precision + 1)])
        x *= 2.0**0.5
        x += self.ksi_0[k] * t
        x /= (np.pi)**0.5
        x += (np.pi)**0.5 * np.sum(self.ksi_0[0:k])
        return x
    
    def _build_ksi(self,times):
        k = self._get_bound(np.max(times))
        if k >= len(self.ksi_0):
            self.ksi_0 = self.ksi_0 + list(np.random.normal(size=k - len(self.ksi_0) + 1))

        need_size = 0
#       build necessary ksi 
        k_unique = np.unique(self._get_bound_vect(times))
        need_size = sum(1 for k in k_unique if k not in self.ksi)
        new_ksi = np.random.normal(size=need_size*self.precision)
#       assign ksi
        for i in range(len(k_unique)):
            k = k_unique[i]
            self.ksi[k] = new_ksi[i*self.precision:(i+1)*self.precision]
    
    def __getitem__(self,times):
        self._build_ksi(times)
        return self._calc_X_vect(times)

# %%
def winer_process_path(end_time, step, precision=10000):

# %%
a = WinerProcess(1000)
times = np.linspace(0,1000,1000)
# %time y = a[times]
plt.plot(times,y)
# Out:
# CPU times: user 1.58 s, sys: 14.5 ms, total: 1.6 s
# Wall time: 1.59 s

# %%
a = [WinerProcess(100) for i in range(10)]
plt.figure(figsize=(12,5))

times = np.linspace(0,100,1000)
for i in np.arange(10):
    # %time y = a[i][times]
    plt.plot(times,y)
# Out:
# CPU times: user 191 ms, sys: 2 ms, total: 193 ms
# Wall time: 194 ms
# CPU times: user 174 ms, sys: 281 µs, total: 174 ms
# Wall time: 175 ms
# CPU times: user 196 ms, sys: 826 µs, total: 197 ms
# Wall time: 198 ms
# CPU times: user 197 ms, sys: 3.51 ms, total: 200 ms
# Wall time: 205 ms
# CPU times: user 216 ms, sys: 3.22 ms, total: 220 ms
# Wall time: 226 ms
# CPU times: user 464 ms, sys: 13.3 ms, total: 477 ms
# Wall time: 515 ms
# CPU times: user 370 ms, sys: 9.12 ms, total: 379 ms
# Wall time: 395 ms
# CPU times: user 200 ms, sys: 607 µs, total: 200 ms
# Wall time: 200 ms
# CPU times: user 192 ms, sys: 845 µs, total: 193 ms
# Wall time: 194 ms
# CPU times: user 404 ms, sys: 9.8 ms, total: 414 ms
# Wall time: 441 ms

# %%
plt.figure(figsize=(20, 12))
for i in range
plt.subplot(3, 3, i * 3 + j + 1)

# %%
Wt = WinerProcess()
t = np.linspace(0, 10 ** 7, 10 ** 5)
# %time values = Wt[t]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/alex/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1826         try:
# -> 1827             sum = a.sum
#    1828         except AttributeError:
#
# AttributeError: 'list' object has no attribute 'sum'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-992fdbe278f8> in <module>()
#       1 Wt = WinerProcess()
#       2 t = np.linspace(0, 10 ** 7, 10 ** 5)
# ----> 3 get_ipython().magic('time values = Wt[t]')
#
# /Users/alex/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2334         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2335         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2336         return self.run_line_magic(magic_name, magic_arg_s)
#    2337
#    2338     #-------------------------------------------------------------------------
#
# /Users/alex/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2255                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2256             with self.builtin_trap:
# -> 2257                 result = fn(*args,**kwargs)
#    2258             return result
#    2259
#
# <decorator-gen-60> in time(self, line, cell, local_ns)
#
# /Users/alex/anaconda/lib/python3.5/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/alex/anaconda/lib/python3.5/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1165         else:
#    1166             st = clock2()
# -> 1167             exec(code, glob, local_ns)
#    1168             end = clock2()
#    1169             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-19-627eafb1e0ff> in __getitem__(self, times)
#      43     def __getitem__(self,times):
#      44         self._build_ksi(times)
# ---> 45         return self._calc_X_vect(times)
#      46
#
# /Users/alex/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    1809             vargs.extend([kwargs[_n] for _n in names])
#    1810
# -> 1811         return self._vectorize_call(func=func, args=vargs)
#    1812
#    1813     def _get_ufunc_and_otypes(self, func, args):
#
# /Users/alex/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    1878                       for _a in args]
#    1879
# -> 1880             outputs = ufunc(*inputs)
#    1881
#    1882             if ufunc.nout == 1:
#
# <ipython-input-19-627eafb1e0ff> in _calc_X(self, t)
#      23         x += self.ksi_0[k] * t
#      24         x /= (np.pi)**0.5
# ---> 25         x += (np.pi)**0.5 * np.sum(self.ksi_0[0:k])
#      26         return x
#      27
#
# /Users/alex/anaconda/lib/python3.5/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims)
#    1828         except AttributeError:
#    1829             return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1830                                  out=out, keepdims=keepdims)
#    1831         # NOTE: Dropping the keepdims parameters here...
#    1832         return sum(axis=axis, dtype=dtype, out=out)
#
# /Users/alex/anaconda/lib/python3.5/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# KeyboardInterrupt:
